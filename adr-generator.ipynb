# %% [markdown]
# # Architecture Decision Record (ADR) Generation
#
# ## What is a ADR?
#
# ADRs are a best practice for documenting why an architecture is chosen. The cloud is an evolving product. The architectural choices made today are based on the features available to us. Features could be different tomorrow, so documenting the decision process allows later contributors to understand why systems are architected a certain way.
#
# **Relevant links:** (alphabetical order)
#  * https://adr.github.io/
#  * https://cloud.google.com/architecture/architecture-decision-records
#  * https://docs.aws.amazon.com/prescriptive-guidance/latest/architectural-decision-records
#  * https://learn.microsoft.com/en-us/azure/architecture/guide/technology-choices (same concept)
#
# ## How can Lexical.cloud be utilized for architectural decisions?
#
# Lexical.cloud is a data source about multi-cloud! By utilizing the same data from the analysis of a release, we can consider what tools are appropriate with the process of elimination. Just run `transform-lc.pynb` to generate the data required for following along.
#
# **Disclaimer:** Decisions can only be as good as the data used to make them, so keep a lookout for data issues.
#
# ### Load the data

# %%
import pandas as pd

products_df = pd.read_json("data/products.json")
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        277 non-null    object
#  1   providers   277 non-null    object
#  2   services    277 non-null    object
#  3   domains     277 non-null    object
#  4   categories  277 non-null    object
#  5   features    66 non-null     object
#  6   links       277 non-null    object
#  7   type        277 non-null    object
#  8   labels      3 non-null      object
# dtypes: object(9)
# memory usage: 19.6+ KB

# %% [markdown]
# ### What type of service is being selected? **(Database)**
#
# We'll consider all known clouds, but we could filter from the start.

# %%
#provider_type = 'aws'
service_type = 'database'

service_products_df = (
    products_df
        .query("type == 'product'")
        .explode('providers')
        #.query("providers == @provider_type")
        .explode('services')
        .query("services == @service_type")
)

service_products_df.head(5)
# Out:
#                                   name providers  services  \
# 51                       Amazon Athena       aws  database
# 52                       Amazon Aurora       aws  database
# 53                     Amazon DynamoDB       aws  database
# 54                  Amazon ElastiCache       aws  database
# 55  Amazon Relational Database Service       aws  database
#
#                                            domains  \
# 51         [big data, data management, serverless]
# 52  [data management, managed service, serverless]
# 53                   [data management, serverless]
# 54                               [managed service]
# 55              [data management, managed service]
#
#                                   categories  \
# 51        [sql compliant, unstructured data]
# 52            [relational db, sql compliant]
# 53  [document db, key-value store, nosql db]
# 54                                 [caching]
# 55            [relational db, sql compliant]
#
#                                             features  \
# 51                                               NaN
# 52                               [mysql, postgresql]
# 53                                               NaN
# 54                                               NaN
# 55  [mysql, postgresql, mariadb, sql server, oracle]
#
#                                              links     type labels
# 51       {'self': '/products/database/aws/athena'}  product    NaN
# 52       {'self': '/products/database/aws/aurora'}  product    NaN
# 53     {'self': '/products/database/aws/dynamodb'}  product    NaN
# 54  {'self': '/products/database/aws/elasticache'}  product    NaN
# 55          {'self': '/products/database/aws/rds'}  product    NaN

# %% [markdown]
# ### What attributes do we have to compare?
#
# Let's turn the entire taxonomy into our decision criteria.

# %%
# combine domains, categories, features and labels into one column for pivot
service_products_df['taxonomy'] = ( 
    service_products_df.domains +
    service_products_df.categories + 
    # the rest are known to be optional
    service_products_df.features.fillna("").apply(list) + 
    service_products_df.labels.fillna("").apply(list)
).map(set).map(list)

pivot_column = 'taxonomy'
pivot_products_df = (
    service_products_df
        .filter(items=['name',pivot_column])
        .explode(pivot_column)
        .groupby(['name',pivot_column]).size().reset_index(name='count')
        .pivot('name',pivot_column,'count').fillna(0, downcast='infer')
)

pivot_products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, AWS Database Migration Service to Google Cloud Spanner
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   big data            22 non-null     int64
#  1   caching             22 non-null     int64
#  2   data management     22 non-null     int64
#  3   data warehousing    22 non-null     int64
#  4   database migration  22 non-null     int64
#  5   document db         22 non-null     int64
#  6   edge computing      22 non-null     int64
#  7   key-value store     22 non-null     int64
#  8   managed service     22 non-null     int64
#  9   mariadb             22 non-null     int64
#  10  mysql               22 non-null     int64
#  11  nosql db            22 non-null     int64
#  12  oracle              22 non-null     int64
#  13  postgresql          22 non-null     int64
#  14  relational db       22 non-null     int64
#  15  serverless          22 non-null     int64
#  16  sql compliant       22 non-null     int64
#  17  sql server          22 non-null     int64
#  18  unstructured data   22 non-null     int64
# dtypes: int64(19)
# memory usage: 3.4+ KB

# %% [markdown]
# ### What attribute is most important for this scenario? **(SQL Compliant)**
#
# There could be multiple, but we'll just start with one. The reason should be documented.

# %%
decision_requirement = 'sql compliant'
decision_matrix_df = (
    pivot_products_df
        .loc[pivot_products_df[decision_requirement] == 1]
)

decision_matrix_df
# Out:
# taxonomy                            big data  caching  data management  \
# name
# Amazon Athena                              1        0                1
# Amazon Aurora                              0        0                1
# Amazon Relational Database Service         0        0                1
# Azure Database for MySQL                   0        0                1
# Azure Database for PostgreSQL              0        0                1
# Azure SQL Database                         0        0                1
# Azure SQL Edge                             0        0                1
# Azure SQL Managed Instance                 0        0                1
# Google Cloud BigQuery                      1        0                1
# Google Cloud SQL                           0        0                1
# Google Cloud Spanner                       0        0                1
#
# taxonomy                            data warehousing  database migration  \
# name
# Amazon Athena                                      0                   0
# Amazon Aurora                                      0                   0
# Amazon Relational Database Service                 0                   0
# Azure Database for MySQL                           0                   0
# Azure Database for PostgreSQL                      0                   0
# Azure SQL Database                                 0                   0
# Azure SQL Edge                                     0                   0
# Azure SQL Managed Instance                         0                   0
# Google Cloud BigQuery                              1                   0
# Google Cloud SQL                                   0                   0
# Google Cloud Spanner                               0                   0
#
# taxonomy                            document db  edge computing  \
# name
# Amazon Athena                                 0               0
# Amazon Aurora                                 0               0
# Amazon Relational Database Service            0               0
# Azure Database for MySQL                      0               0
# Azure Database for PostgreSQL                 0               0
# Azure SQL Database                            0               0
# Azure SQL Edge                                0               1
# Azure SQL Managed Instance                    0               0
# Google Cloud BigQuery                         0               0
# Google Cloud SQL                              0               0
# Google Cloud Spanner                          0               0
#
# taxonomy                            key-value store  managed service  mariadb  \
# name
# Amazon Athena                                     0                0        0
# Amazon Aurora                                     0                1        0
# Amazon Relational Database Service                0                1        1
# Azure Database for MySQL                          0                1        0
# Azure Database for PostgreSQL                     0                1        0
# Azure SQL Database                                0                1        0
# Azure SQL Edge                                    0                0        0
# Azure SQL Managed Instance                        0                1        0
# Google Cloud BigQuery                             0                0        0
# Google Cloud SQL                                  0                1        0
# Google Cloud Spanner                              0                1        0
#
# taxonomy                            mysql  nosql db  oracle  postgresql  \
# name
# Amazon Athena                           0         0       0           0
# Amazon Aurora                           1         0       0           1
# Amazon Relational Database Service      1         0       1           1
# Azure Database for MySQL                1         0       0           0
# Azure Database for PostgreSQL           0         0       0           1
# Azure SQL Database                      0         0       0           0
# Azure SQL Edge                          0         0       0           0
# Azure SQL Managed Instance              0         0       0           0
# Google Cloud BigQuery                   0         0       0           0
# Google Cloud SQL                        1         0       0           1
# Google Cloud Spanner                    0         0       0           0
#
# taxonomy                            relational db  serverless  sql compliant  \
# name
# Amazon Athena                                   0           1              1
# Amazon Aurora                                   1           1              1
# Amazon Relational Database Service              1           0              1
# Azure Database for MySQL                        1           0              1
# Azure Database for PostgreSQL                   1           0              1
# Azure SQL Database                              1           1              1
# Azure SQL Edge                                  1           0              1
# Azure SQL Managed Instance                      1           0              1
# Google Cloud BigQuery                           0           1              1
# Google Cloud SQL                                1           0              1
# Google Cloud Spanner                            1           0              1
#
# taxonomy                            sql server  unstructured data
# name
# Amazon Athena                                0                  1
# Amazon Aurora                                0                  0
# Amazon Relational Database Service           1                  0
# Azure Database for MySQL                     0                  0
# Azure Database for PostgreSQL                0                  0
# Azure SQL Database                           0                  0
# Azure SQL Edge                               0                  0
# Azure SQL Managed Instance                   0                  0
# Google Cloud BigQuery                        0                  1
# Google Cloud SQL                             1                  0
# Google Cloud Spanner                         0                  0

# %% [markdown]
# ## Begin the Decision Record
#
# All decisions made to this point should be documented here.
#
# ### What tradeoffs exist for our scenario? **(SQL Databases)**
#
# Let's discard columns with no differences and start considering the best SQL compliant database for our purpose.

# %%
adr = (
    decision_matrix_df
        # drop columns with all 0
        .loc[:, (decision_matrix_df != 0).any(axis=0)]
        # drop columns with all 1
        .loc[:, (decision_matrix_df != 1).any(axis=0)]
        # use Y or N not 1 or 0
        .replace({0: 'N', 1: 'Y' })
)

adr
# Out:
# taxonomy                           big data data warehousing edge computing  \
# name
# Amazon Athena                             Y                N              N
# Amazon Aurora                             N                N              N
# Amazon Relational Database Service        N                N              N
# Azure Database for MySQL                  N                N              N
# Azure Database for PostgreSQL             N                N              N
# Azure SQL Database                        N                N              N
# Azure SQL Edge                            N                N              Y
# Azure SQL Managed Instance                N                N              N
# Google Cloud BigQuery                     Y                Y              N
# Google Cloud SQL                          N                N              N
# Google Cloud Spanner                      N                N              N
#
# taxonomy                           managed service mariadb mysql oracle  \
# name
# Amazon Athena                                    N       N     N      N
# Amazon Aurora                                    Y       N     Y      N
# Amazon Relational Database Service               Y       Y     Y      Y
# Azure Database for MySQL                         Y       N     Y      N
# Azure Database for PostgreSQL                    Y       N     N      N
# Azure SQL Database                               Y       N     N      N
# Azure SQL Edge                                   N       N     N      N
# Azure SQL Managed Instance                       Y       N     N      N
# Google Cloud BigQuery                            N       N     N      N
# Google Cloud SQL                                 Y       N     Y      N
# Google Cloud Spanner                             Y       N     N      N
#
# taxonomy                           postgresql relational db serverless  \
# name
# Amazon Athena                               N             N          Y
# Amazon Aurora                               Y             Y          Y
# Amazon Relational Database Service          Y             Y          N
# Azure Database for MySQL                    N             Y          N
# Azure Database for PostgreSQL               Y             Y          N
# Azure SQL Database                          N             Y          Y
# Azure SQL Edge                              N             Y          N
# Azure SQL Managed Instance                  N             Y          N
# Google Cloud BigQuery                       N             N          Y
# Google Cloud SQL                            Y             Y          N
# Google Cloud Spanner                        N             Y          N
#
# taxonomy                           sql server unstructured data
# name
# Amazon Athena                               N                 Y
# Amazon Aurora                               N                 N
# Amazon Relational Database Service          Y                 N
# Azure Database for MySQL                    N                 N
# Azure Database for PostgreSQL               N                 N
# Azure SQL Database                          N                 N
# Azure SQL Edge                              N                 N
# Azure SQL Managed Instance                  N                 N
# Google Cloud BigQuery                       N                 Y
# Google Cloud SQL                            Y                 N
# Google Cloud Spanner                        N                 N

# %% [markdown]
# ### What other requirements are there for this scenario? **(Serverless)**
#
# We would document the reasoning before proceeding.

# %%
adr = adr.query("serverless == 'Y'")

adr
# Out:
# taxonomy              big data data warehousing edge computing  \
# name
# Amazon Athena                Y                N              N
# Amazon Aurora                N                N              N
# Azure SQL Database           N                N              N
# Google Cloud BigQuery        Y                Y              N
#
# taxonomy              managed service mariadb mysql oracle postgresql  \
# name
# Amazon Athena                       N       N     N      N          N
# Amazon Aurora                       Y       N     Y      N          Y
# Azure SQL Database                  Y       N     N      N          N
# Google Cloud BigQuery               N       N     N      N          N
#
# taxonomy              relational db serverless sql server unstructured data
# name
# Amazon Athena                     N          Y          N                 Y
# Amazon Aurora                     Y          Y          N                 N
# Azure SQL Database                Y          Y          N                 N
# Google Cloud BigQuery             N          Y          N                 Y

# %% [markdown]
# ### What other requirements? **(MySQL)**
#
# We would document the reasoning before proceeding.

# %%
adr = adr.query("mysql == 'Y'")

adr
# Out:
# taxonomy      big data data warehousing edge computing managed service  \
# name
# Amazon Aurora        N                N              N               Y
#
# taxonomy      mariadb mysql oracle postgresql relational db serverless  \
# name
# Amazon Aurora       N     Y      N          Y             Y          Y
#
# taxonomy      sql server unstructured data
# name
# Amazon Aurora          N                 N

# %% [markdown]
# ## Decision Reached!
#
# Let's review all the attributes of what was selected.

# %%
decision = (
    decision_matrix_df
        .loc[adr.index[0]]
        .replace({0: 'N', 1: 'Y' })
        .to_frame()
)

decision
# Out:
#                    Amazon Aurora
# taxonomy
# big data                       N
# caching                        N
# data management                Y
# data warehousing               N
# database migration             N
# document db                    N
# edge computing                 N
# key-value store                N
# managed service                Y
# mariadb                        N
# mysql                          Y
# nosql db                       N
# oracle                         N
# postgresql                     Y
# relational db                  Y
# serverless                     Y
# sql compliant                  Y
# sql server                     N
# unstructured data              N

# %% [markdown]
# ### Satisfied?
#
# Document it by exporting and version controling information from this notebook! The available services could be different tomorrow. The system requirements could be different as well. Archiving the state of system requirements and the available tooling is a must.

# %% [markdown]
# # Stay tuned!
#
# There is a plan to make this functionality more developer friendly. Coming soon to an IDE near you :)
